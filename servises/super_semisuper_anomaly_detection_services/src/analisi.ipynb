# %%
import pandas as pd
from general_services import *
from base_services import *
from anomalyDetection import *

# %%
file_name = "ae_test.csv"
df = pd.read_csv("../data/"+file_name, sep=';')
df
# Out:
#               timestamp    m1   m2       m3     m4  label
# 0   2020-06-08 17:00:00  1233  222  32.3200  32.12      0
# 1   2020-06-08 17:00:30  1233  222  32.3200  32.12      0
# 2   2020-06-08 17:01:00    13  222  32.3200  32.12      1
# 3   2020-06-08 17:01:30    33  222  32.3200  32.12      1
# 4   2020-06-08 17:02:00    33  222   3.3200  32.12      0
# 5   2020-06-08 17:02:30   233   22  32.9532  32.12      0
# 6   2020-06-08 17:03:00   233   42   1.3200  32.12      1
# 7   2020-06-08 17:03:30   123  522   2.3200  32.12      0
# 8   2020-06-08 17:04:00    13    2  32.3200   2.12      0
# 9   2020-06-08 17:04:30    12  222  32.3200  32.12      0
# 10  2020-06-08 17:05:00    13  222   0.3200  52.12      0
# 11  2020-06-08 17:05:30    83  222   0.3200  52.42      1
# 12  2020-06-08 17:06:00    33  222   3.3200  32.12      0
# 13  2020-06-08 17:06:30    28   22   2.2000  32.12      0
# 14  2020-06-08 17:07:00    98   42   7.3200  32.12      1
# ...

# %%
for ft in df.columns:
    check_for_nan = df[ft].isnull().sum()
    print("{}: {} Nan".format(ft, check_for_nan))
# Out:
# timestamp: 0 Nan
# m1: 0 Nan
# m2: 0 Nan
# m3: 0 Nan
# m4: 0 Nan
# label: 0 Nan

# %%
keras_model, scaler, sum = semisup_autoencoder(file_name, sep=';')
# Out:
# [adssae:semisup_autoencoder] Autoencoder model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 21)                0
# _________________________________________________________________
# dense (Dense)                (None, 210)               4620
# _________________________________________________________________
# dense_1 (Dense)              (None, 210)               44310
# _________________________________________________________________
# dense_2 (Dense)              (None, 210)               44310
# _________________________________________________________________
# dense_3 (Dense)              (None, 210)               44310
# _________________________________________________________________
# dense_4 (Dense)              (None, 210)               44310
# _________________________________________________________________
# ...
